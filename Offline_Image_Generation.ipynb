# %%
# !pip install diffusers

# %%
# !pip install accelerate

# %%
# !pip install transformers

# %%
# !pip install safetensors

# %%
# !pip install scipy

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image

# Use GPU if available
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load pre-trained Stable Diffusion pipeline
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16 if device == "cuda" else torch.float32
)

pipe = pipe.to(device)
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]

# %%
prompt = "create the painting of mountains "
image = pipe(prompt).images[0]

# Show the generated image
image.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image.save("generated_image.png")

# %%
prompts = [
    "A rat near food",
    "A girl with  Ladies in the garden ",
    "A running horse in the cloud ",
]

for i, p in enumerate(prompts):
    img = pipe(p).images[0]
    img.save(f"image_{i+1}.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompts1 = [

    "A girl dance"
]

for i, p in enumerate(prompts1):
    img = pipe(p).images[0]
    img.save(f"image_{i+1}.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
img.save("image_4.png")
